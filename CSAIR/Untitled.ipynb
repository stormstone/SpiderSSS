# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_total = pd.read_csv('./data/df_total.csv')
df_total['depDate'] = pd.to_datetime(df_total['depDate'])
df_total.head()
# Out:
#      depDate  totalLsv  totalBkd
# 0 2020-08-26     46749     41477
# 1 2020-08-27     46004     42639
# 2 2020-08-28     46616     38347
# 3 2020-08-29     45939     40839
# 4 2020-08-30     46449     36871

# %%
plt.figure(figsize=(20,6))
sns.lineplot(df_total['depDate'], df_total['totalLsv'])
sns.lineplot(df_total['depDate'], df_total['totalBkd'])
