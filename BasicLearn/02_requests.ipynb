# %% [markdown]
# # requests库基本使用
# -https://cuiqingcai.com/5514.html
#
# requests比urllib更强大。

# %%
# !pip list | grep requests
# Out:
# requests                           2.22.0
# requests-oauthlib                  1.3.0

# %%
import requests

# %% [markdown]
# ## 1、基本使用

# %% [markdown]
# ### get请求

# %%
r = requests.get('http://httpbin.org/get')
print(r.text)

print(type(r.status_code), r.status_code)
print(type(r.headers), r.headers)
print(type(r.cookies), r.cookies)
print(type(r.url), r.url)
print(type(r.history), r.history)
# Out:
# {
#   "args": {},
#   "headers": {
#     "Accept": "*/*",
#     "Accept-Encoding": "gzip, deflate",
#     "Host": "httpbin.org",
#     "User-Agent": "python-requests/2.22.0",
#     "X-Amzn-Trace-Id": "Root=1-60eeb14f-12d9bbf333708aaf077d7172"
#   },
#   "origin": "118.122.120.66",
#   "url": "http://httpbin.org/get"
# }
#
# <class 'int'> 200
# <class 'requests.structures.CaseInsensitiveDict'> {'Date': 'Wed, 14 Jul 2021 09:41:35 GMT', 'Content-Type': 'application/json', 'Content-Length': '307', 'Connection': 'keep-alive', 'Server': 'gunicorn/19.9.0', 'Access-Control-Allow-Origin': '*', 'Access-Control-Allow-Credentials': 'true'}
# <class 'requests.cookies.RequestsCookieJar'> <RequestsCookieJar[]>
# <class 'str'> http://httpbin.org/get
# <class 'list'> []

# %%
# 参数设置
data = {
    'name': 'germey',
    'age': 22
}
r = requests.get("http://httpbin.org/get", params=data)
print(r.text)
# Out:
# {
#   "args": {
#     "age": "22",
#     "name": "germey"
#   },
#   "headers": {
#     "Accept": "*/*",
#     "Accept-Encoding": "gzip, deflate",
#     "Host": "httpbin.org",
#     "User-Agent": "python-requests/2.22.0",
#     "X-Amzn-Trace-Id": "Root=1-60eeb061-76ac5bf015d318343cf69465"
#   },
#   "origin": "118.122.120.66",
#   "url": "http://httpbin.org/get?name=germey&age=22"
# }

# %% [markdown]
# ### 添加headers

# %%
r = requests.get("https://www.zhihu.com/explore")
print(r.status_code)
print(r.text)
# Out:
# 403
# <html>
# <head><title>403 Forbidden</title></head>
# <body bgcolor="white">
# <center><h1>403 Forbidden</h1></center>
# <hr><center>openresty</center>
# </body>
# </html>

# %%
headers = {
    'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/52.0.2743.116 Safari/537.36'
}
r = requests.get("https://www.zhihu.com/explore", headers=headers)
print(r.status_code)
# print(r.text)
# Out:
# 200

# %% [markdown]
# ### post请求

# %%
data = {'name': 'germey', 'age': '22'}
r = requests.post("http://httpbin.org/post", data=data)
print(r.text)
# Out:
# {
#   "args": {},
#   "data": "",
#   "files": {},
#   "form": {
#     "age": "22",
#     "name": "germey"
#   },
#   "headers": {
#     "Accept": "*/*",
#     "Accept-Encoding": "gzip, deflate",
#     "Content-Length": "18",
#     "Content-Type": "application/x-www-form-urlencoded",
#     "Host": "httpbin.org",
#     "User-Agent": "python-requests/2.22.0",
#     "X-Amzn-Trace-Id": "Root=1-60eeb137-75a3eb2f6f1320873a2816f7"
#   },
#   "json": null,
#   "origin": "118.122.120.66",
#   "url": "http://httpbin.org/post"
# }

# %% [markdown]
# ## 2、高级用法

# %% [markdown]
# ### 2.1 文件上传

# %%
files = {'file': open('requests_test_file.txt', 'rb')}
r = requests.post("http://httpbin.org/post", files=files)
print(r.text)
# Out:
# {
#   "args": {},
#   "data": "",
#   "files": {
#     "file": "test"
#   },
#   "form": {},
#   "headers": {
#     "Accept": "*/*",
#     "Accept-Encoding": "gzip, deflate",
#     "Content-Length": "162",
#     "Content-Type": "multipart/form-data; boundary=7de5c575915e9c065e1d0be4159d9167",
#     "Host": "httpbin.org",
#     "User-Agent": "python-requests/2.22.0",
#     "X-Amzn-Trace-Id": "Root=1-60eeb22c-0c4f337c6fa892693aef2dc4"
#   },
#   "json": null,
#   "origin": "118.122.120.66",
#   "url": "http://httpbin.org/post"
# }

# %% [markdown]
# ### 2.2 Cookies

# %%
r = requests.get("https://www.baidu.com")
print(r.cookies)
for key, value in r.cookies.items():
    print(key + '=' + value)
# Out:
# <RequestsCookieJar[<Cookie BDORZ=27315 for .baidu.com/>]>
# BDORZ=27315

# %%
# 设置cookie
headers = {
    'Cookie': '_zap=38453d69-d26a-4a0b-9525-cdce7b524c3e; _ga=GA1.2.2130910279.1589599779; d_c0="AGBdrZn1RhGPTtlYZX1BFxAx4cGD5v3krlA=|1589599779"; __utma=51854390.2130910279.1589599779.1603865334.1603865334.1; __utmv=51854390.100-1|2=registration_date=20151005=1^3=entry_date=20151005=1; OUTFOX_SEARCH_USER_ID_NCOO=1564732256.9951167; q_c1=3aa02a0b746242eea6c96990c2890240|1614235306000|1591065792000; tshl=; _xsrf=aQaCo9IsexQirkCx0JEEHzgINTklWpZH; __snaker__id=8qCISvrmLc1jwR7l; _9755xjdesxxd_=32; YD00517437729195%3AWM_TID=7hpW2jOu5zVFUEUQRQIvg5GVLQHkB5sf; gdxidpyhxdE=VM%2Bq9USAaI1JJAgwVX%5CsiNhXp%2BrtjtTUs%2BuYtOK2jm4NuqSK%5COd2N%2FQ8yRLoHEJiDGclYmsnCH4SJ4cB7Kns%5CrEiepoumjW4T93OlIx9axNr0%5CCI3mz%2FsWPZNaeVlW6UfCCPmTJYN9%2FI5xWDb%5CQPaRYN%2F3PXX4sMWt8dUQ3fRz9qpa1t%3A1622628060804; YD00517437729195%3AWM_NI=oEocuIm5MGC5Hj2E9%2B4wfy%2F5u%2FaRedRCx6HKuw6xvOwt2wLX0sO5hqO8D%2Bn5YOcZz%2BSDRKSNA6emD%2B6LyyHB71%2F0xbyxr%2F3LOEfgnTK8q5IRMMNZfVA1RWwhxrwF2ARUdHU%3D; YD00517437729195%3AWM_NIKE=; z_c0="2|1:0|10:1622627164|4:z_c0|92:Mi4xZzh3bkFnQUFBQUFBWUYydG1mVkdFU1lBQUFCZ0FsVk5YS0drWVFDRXFMOFRyUzRVS1FocXYxTmpwWjlVU2ZCZ053|bc8d6157af88cba8c4f490d1bb05ec94d0edf7244679b9b713ddcdad87568df9"; Hm_lvt_98beee57fd2ef70ccdd5ca52b9740c49=1626238095,1626244433,1626244498,1626244867; tst=h; SESSIONID=RBts9X9PFnGF7lYnIHWHuAWMeXqAM5HfeHWa2e0Lc4d; JOID=UVASAkuU4yREqExRGJYbN6FUeNINza5WNpIfZ07RhmwEniMDefVYzSagSFgfG9fO6vkM8Fw-Nej3GVC7pF-Hi4M=; osd=WlkSBkuf6iRAqEdYGJIbPKhUfNIGxK5SNpkWZ0rRjWUEmiMIcPVczS2pSFwfEN7O7vkH-Vw6NeP-GVS7r1aHj4M=; Hm_lpvt_98beee57fd2ef70ccdd5ca52b9740c49=1626255982; KLBRSID=fb3eda1aa35a9ed9f88f346a7a3ebe83|1626255986|1626255969',
    'Host': 'www.zhihu.com',
    'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/53.0.2785.116 Safari/537.36',
}
r = requests.get('https://www.zhihu.com/people/stormstone8/posts', headers=headers)
print(r.text)
# Out:
# <!doctype html>
# ...

# %% [markdown]
# ### 2.3 会话维持
# 在 requests 中，如果直接利用 get() 或 post() 等方法的确可以做到模拟网页的请求，但是这实际上是相当于不同的会话，也就是说相当于你用了两个浏览器打开了不同的页面。
#
# 设想这样一个场景，第一个请求利用 post() 方法登录了某个网站，第二次想获取成功登录后的自己的个人信息，你又用了一次 get() 方法去请求个人信息页面。实际上，这相当于打开了两个浏览器，是两个完全不相关的会话，能成功获取个人信息吗？那当然不能。
#
# 有小伙伴可能说了，我在两次请求时设置一样的 cookies 不就行了？可以，但这样做起来显得很烦琐，我们有更简单的解决方法。
#
# 其实解决这个问题的主要方法就是维持同一个会话，也就是相当于打开一个新的浏览器选项卡而不是新开一个浏览器。但是我又不想每次设置 cookies，那该怎么办呢？这时候就有了新的利器 ——Session 对象。
#
# 利用它，我们可以方便地维护一个会话，而且不用担心 cookies 的问题，它会帮我们自动处理好。

# %%
requests.get('http://httpbin.org/cookies/set/number/123456789')
r = requests.get('http://httpbin.org/cookies')
print(r.text)
# Out:
# {
#   "cookies": {}
# }

# %%
s = requests.Session()
s.get('http://httpbin.org/cookies/set/number/123456789')
r = s.get('http://httpbin.org/cookies')
print(r.text)
# Out:
# {
#   "cookies": {
#     "number": "123456789"
#   }
# }

# %% [markdown]
# ### 2.4 代理

# %%
proxies = {
    'http': 'http://127.0.0.1:10809',
    'https': 'https://127.0.0.1:10809'
}

requests.get("http://www.baidu.com", proxies=proxies)
# Out:
# <Response [200]>
